# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
# Install tqdm on floydhub
# !pip install tqdm
# Out:
# Collecting tqdm
#   Downloading tqdm-4.11.2-py2.py3-none-any.whl (46kB)
#     100% |████████████████████████████████| 51kB 3.3MB/s ta 0:00:01
# Installing collected packages: tqdm
# Successfully installed tqdm-4.11.2

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:13, 2.38MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 0.00001
words_counter = Counter(int_words)
total_count = len(int_words)

# frequency of word  w in the total dataset.
words_freq = {w: count / total_count for w, count in words_counter.items()}

# probability that a word is discarded
prob_discard_word = {word: 1 - np.sqrt(threshold/(words_freq[word])) for word in words_counter}
    
# The final subsampled word list    
train_words = [word for word in int_words if prob_discard_word[word] < random.random() ]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    # Your code here
    
    #select randomly a number R in range  <1;C>
    R = random.randint(1, window_size+1)
    start_idx = idx - R if (idx - R) > 0 else 0
    end_idx = idx + R 
    target = set ( words[start_idx:idx] + words[idx +1: end_idx])
    
    return list(target)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(dtype=tf.int32, shape=[None], name='inputs')
    labels = tf.placeholder(dtype=tf.int32, shape=[None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform(dtype=tf.float32, shape=[n_vocab,n_embedding],minval=-1.0, maxval=1.0), 
                            name ='embedding') 
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs )

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal(dtype=tf.float32, shape=[n_vocab,n_embedding], mean=0.0, stddev=0.1), 
                            name ='softmax_w')
    # create softmax biases here
    softmax_b = tf.zeros(dtype=tf.float32, shape=[n_vocab], name='softmax_b')
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(weights=softmax_w, biases=softmax_b, 
                                      labels=labels,
                                      inputs=embed,
                                      num_sampled=n_sampled,
                                      num_classes=n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6548 0.0963 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6226 0.0936 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5357 0.0926 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6546 0.0916 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5453 0.0931 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.6099 0.0953 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.6267 0.0948 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.6221 0.0966 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5543 0.0992 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.5280 0.1015 sec/batch
# Nearest to world: arlo, estep, chondrites, monocotyledons, xb, linnaeus, entrepreneurial, hay,
# Nearest to four: tambo, suicide, paradise, schwarzwald, goat, exterminating, hospitals, attendees,
# Nearest to th: outpaced, whitewash, discount, restorative, orangutans, stead, slight, theobald,
# Nearest to system: vineyard, miramax, netting, wasted, inflows, vacuoles, brahmins, initialize,
# Nearest to these: portus, jesuits, expressing, transcribing, madge, paper, touchscreen, hiding,
# Nearest to this: addressable, landscapes, neatly, carrier, brahmic, scrutiny, staubach, duty,
# Nearest to its: spellman, casteljau, dbm, galatia, rectifiers, dpp, dakini, discriminatory,
# Nearest to be: telecast, overthrow, ambassadorial, transmuted, stags, pearson, feast, eui,
# Nearest to gold: totaled, verbal, covers, persecutor, mourned, repeal, plural, nubians,
# Nearest to engine: fiqh, captive, channelling, quake, rohypnol, bubalus, aqdas, manipulate,
# Nearest to applications: transits, yerba, complexes, model, niches, hideo, cliffe, asherah,
# Nearest to scale: asteroids, wobbly, amillennialism, buscema, daiko, eurythmics, jyutping, crewed,
# Nearest to pre: trolltech, cabal, faroese, miracle, pesach, balasingham, inked, bc,
# Nearest to construction: hazmi, osage, landslides, williamite, unspectacular, own, comforted, quizzes,
# Nearest to hold: bhutan, borgia, infirmary, teleoperation, gokturks, btu, paymaster, pitied,
# Nearest to alternative: precaution, tapes, noblesse, nikolay, intuitive, tuskegee, baleen, excretory,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5955 0.1044 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4840 0.1041 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.4693 0.1060 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.3304 0.1084 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.3062 0.1064 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2617 0.1070 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1872 0.1097 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.1387 0.1074 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0878 0.1082 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0473 0.1090 sec/batch
# Nearest to world: workers, arlo, xb, hay, complete, estep, cheaper, richer,
# Nearest to four: suicide, hospitals, nascent, sides, tambo, register, bring, opponent,
# Nearest to th: slight, whitewash, discount, ch, chance, low, distinctly, infamous,
# Nearest to system: third, x, bevin, familial, joint, actress, wasted, once,
# Nearest to these: expressing, portus, paper, jesuits, follows, criminal, the, transcribing,
# Nearest to this: duty, landscapes, eight, isbn, scrutiny, neatly, carrier, addressable,
# Nearest to its: great, inputs, discriminatory, encoding, spellman, daring, but, galatia,
# Nearest to be: telecast, continues, overthrow, doing, town, feast, member, pearson,
# Nearest to gold: totaled, covers, verbal, repeal, plural, offered, persecutor, mourned,
# Nearest to engine: captive, quake, some, manipulate, com, connection, icon, fiqh,
# Nearest to applications: model, argued, artificial, objects, complexes, scytale, stays, niches,
# Nearest to scale: asteroids, wobbly, phones, august, electrical, arch, quarries, cofactor,
# Nearest to pre: bc, environment, uncertain, trolltech, cabal, miracle, pesach, inked,
# Nearest to construction: own, hazmi, osage, late, production, durations, landslides, mickey,
# Nearest to hold: bhutan, amount, infirmary, fidonet, exaltation, scholarships, evangelical, concept,
# Nearest to alternative: tapes, nikolay, intuitive, precaution, tuskegee, distribute, noblesse, explaining,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9687 0.1142 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9737 0.1111 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9450 0.1101 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8964 0.1103 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8607 0.1107 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8680 0.1093 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8323 0.1106 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8228 0.1113 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8128 0.1101 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7997 0.1111 sec/batch
# Nearest to world: workers, arlo, hay, xb, estep, richer, raiding, michigan,
# Nearest to four: hospitals, opponent, suicide, bring, tambo, celebrating, cage, exterminating,
# Nearest to th: slight, discount, stead, whitewash, zx, outpaced, theobald, guinea,
# Nearest to system: familial, third, bevin, wasted, combatants, vineyard, miramax, iterated,
# Nearest to these: expressing, portus, jesuits, criminal, transcribing, hiding, waste, paper,
# Nearest to this: landscapes, overseas, addressable, neatly, gentiles, carrier, duty, scrutiny,
# Nearest to its: encoding, discriminatory, spellman, inputs, rectifiers, daring, infrastructure, dbm,
# Nearest to be: eu, telecast, feast, doing, overthrow, evil, ambassadorial, attached,
# Nearest to gold: totaled, covers, plural, repeal, verbal, offered, rearrangement, rainfall,
# Nearest to engine: quake, manipulate, com, captive, fiqh, swiss, icon, some,
# Nearest to applications: model, artificial, argued, objects, viewpoints, niches, complexes, stays,
# Nearest to scale: asteroids, wobbly, phones, arch, august, electrical, gathered, gymnastics,
# Nearest to pre: miracle, earls, uncertain, faroese, bc, trolltech, cabal, inked,
# Nearest to construction: own, osage, hazmi, landslides, late, sloppy, mayhem, durations,
# Nearest to hold: bhutan, evangelical, amount, tyrrhenian, concept, infirmary, exaltation, fidonet,
# Nearest to alternative: intuitive, tapes, precaution, explaining, nikolay, distribute, tuskegee, joules,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7999 0.1125 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7965 0.1117 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7588 0.1139 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7344 0.1138 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7661 0.1142 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7351 0.1124 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7408 0.1120 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7737 0.1124 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7153 0.1108 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.7053 0.1122 sec/batch
# Nearest to world: arlo, workers, hay, xb, estep, cracow, investigation, raiding,
# Nearest to four: hospitals, three, two, nine, celebrating, opponent, morley, five,
# Nearest to th: zx, stead, slight, theobald, discount, condemning, whitewash, rio,
# Nearest to system: inflows, vineyard, familial, combatants, iterated, bevin, euphemism, townspeople,
# Nearest to these: portus, expressing, criminal, transcribing, madge, endorsement, jesuits, hiding,
# Nearest to this: landscapes, addressable, gentiles, overseas, neatly, indexes, fragility, duty,
# Nearest to its: infrastructure, encoding, spellman, discriminatory, seceded, dbm, factual, rectifiers,
# Nearest to be: ambassadorial, telecast, eu, attached, transmuted, correct, properties, pearson,
# Nearest to gold: totaled, covers, repeal, plural, verbal, offered, mourned, persecutor,
# Nearest to engine: quake, fiqh, com, manipulate, glucose, goddard, icon, some,
# Nearest to applications: model, artificial, niches, yerba, objects, viewpoints, complexes, recycled,
# Nearest to scale: wobbly, asteroids, electrical, pitchers, barrie, essex, puzzles, arch,
# Nearest to pre: earls, miracle, trolltech, uncertain, faroese, bc, cabal, distracted,
# Nearest to construction: osage, hazmi, own, durations, covers, mayhem, landslides, production,
# Nearest to hold: bhutan, infirmary, persuasion, evangelical, thunderstorm, tyrrhenian, pitied, fidonet,
# Nearest to alternative: precaution, intuitive, tapes, nikolay, explaining, noblesse, joules, tuskegee,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.7052 0.1139 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.7172 0.1111 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6399 0.1129 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6360 0.1125 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6508 0.1119 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6566 0.1118 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6109 0.0816 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5529 0.1135 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5434 0.1110 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5561 0.1103 sec/batch
# Nearest to world: arlo, workers, hay, cracow, xb, estep, linnaeus, averting,
# Nearest to four: two, five, three, natasha, nine, one, juan, jr,
# Nearest to th: zx, focussing, stead, theobald, petros, campus, rio, outpaced,
# Nearest to system: vineyard, inflows, familial, combatants, iterated, euphemism, biology, townspeople,
# Nearest to these: portus, transcribing, poor, expressing, endorsement, follows, waste, paper,
# Nearest to this: landscapes, addressable, gentiles, neatly, indexes, consider, viper, fragility,
# Nearest to its: seceded, discriminatory, spellman, encoding, infrastructure, rectifiers, inputs, bogged,
# Nearest to be: evaluate, doing, correct, attached, properties, eu, transmuted, ambassadorial,
# Nearest to gold: totaled, repeal, covers, plural, persecutor, rainfall, verbal, offered,
# Nearest to engine: quake, com, fiqh, manipulate, glucose, sufferers, icon, some,
# Nearest to applications: model, storage, objects, niches, yerba, artificial, complexes, conventional,
# Nearest to scale: wobbly, asteroids, electrical, barrie, approximated, pitchers, puzzles, polonius,
# Nearest to pre: earls, miracle, cabal, trolltech, distracted, uncertain, bc, inked,
# Nearest to construction: osage, hazmi, durations, production, covers, own, landslides, mayhem,
# Nearest to hold: persuasion, infirmary, borgia, bhutan, paymaster, thunderstorm, pitied, evangelical,
# Nearest to alternative: intuitive, precaution, tapes, nikolay, explaining, noblesse, joules, ack,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5356 0.1132 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5429 0.1126 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.5100 0.1112 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5694 0.1121 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5261 0.1113 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.5099 0.1121 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4565 0.1130 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4236 0.1143 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4699 0.1146 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4740 0.1145 sec/batch
# Nearest to world: arlo, workers, hay, xb, inflow, cracow, estep, linnaeus,
# Nearest to four: two, five, three, natasha, nobis, hospitals, six, one,
# Nearest to th: focussing, outpaced, century, theobald, zx, stead, whitewash, proverbial,
# Nearest to system: vineyard, inflows, pc, iterated, combatants, plus, perpetrator, biology,
# Nearest to these: portus, the, expressing, poor, transcribing, endorsement, paper, warhol,
# Nearest to this: addressable, landscapes, neatly, easterners, viper, gentiles, indexes, consider,
# Nearest to its: infrastructure, spellman, discriminatory, seceded, encoding, exposures, bogged, rectifiers,
# Nearest to be: evaluate, properties, doing, correct, transmuted, problems, demonstrating, ambassadorial,
# Nearest to gold: totaled, covers, repeal, plural, rainfall, persecutor, capita, rearrangement,
# Nearest to engine: quake, com, manipulate, glucose, fiqh, sniping, icon, listed,
# Nearest to applications: model, storage, objects, yerba, artificial, users, niches, complexes,
# Nearest to scale: wobbly, asteroids, electrical, polonius, tasteless, approximated, assortment, barrie,
# Nearest to pre: miracle, earls, uncertain, cabal, distracted, trolltech, bc, inked,
# Nearest to construction: osage, durations, hazmi, production, covers, mayhem, sloppy, own,
# Nearest to hold: persuasion, paymaster, borgia, infirmary, scholarships, concept, gokturks, btu,
# Nearest to alternative: intuitive, precaution, tapes, nikolay, ack, noblesse, explaining, joules,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4548 0.1126 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4508 0.1123 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4720 0.1130 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4437 0.1147 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4060 0.1125 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4780 0.1134 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.4239 0.1126 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.4172 0.1123 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4348 0.1139 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3668 0.1125 sec/batch
# Nearest to world: arlo, workers, hay, xb, linnaeus, inflow, estep, evolutions,
# Nearest to four: two, three, five, one, nine, natasha, six, nobis,
# Nearest to th: century, theobald, focussing, outpaced, stead, zx, whitewash, proverbial,
# Nearest to system: iterated, vineyard, inflows, pc, combatants, perpetrator, plus, biology,
# Nearest to these: portus, expressing, poor, transcribing, endorsement, cycles, warhol, paper,
# Nearest to this: addressable, neatly, fragility, easterners, viper, landscapes, gauntlets, injustices,
# Nearest to its: discriminatory, infrastructure, rectifiers, dpp, spellman, mirabilis, inputs, scouring,
# Nearest to be: evaluate, doing, bottoms, correct, demonstrating, problems, properties, ambassadorial,
# Nearest to gold: totaled, covers, repeal, rainfall, capita, plural, persecutor, boiled,
# Nearest to engine: quake, com, manipulate, glucose, privations, sniping, improved, fiqh,
# Nearest to applications: model, storage, niches, objects, yerba, users, complexes, artificial,
# Nearest to scale: wobbly, asteroids, electrical, approximated, tasteless, polonius, assortment, barrie,
# Nearest to pre: miracle, earls, distracted, uncertain, bc, cabal, inked, trolltech,
# Nearest to construction: osage, production, durations, hazmi, own, sloppy, mayhem, arrangements,
# Nearest to hold: persuasion, infirmary, paymaster, borgia, concept, scholarships, barracuda, btu,
# Nearest to alternative: intuitive, precaution, nikolay, tapes, joules, noblesse, ack, tailored,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.4151 0.1129 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4200 0.1130 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3916 0.1115 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.4080 0.1112 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4249 0.1101 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3848 0.1130 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4178 0.1127 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3950 0.1136 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3749 0.1155 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3557 0.1128 sec/batch
# Nearest to world: arlo, workers, inflow, hay, xb, linnaeus, osama, estep,
# Nearest to four: two, three, five, six, one, runways, seven, nine,
# Nearest to th: century, focussing, theobald, outpaced, proverbial, zx, stead, praetors,
# Nearest to system: pc, iterated, inflows, vineyard, authentication, punch, information, plus,
# Nearest to these: portus, poor, touchscreen, endorsement, transcribing, expressing, the, cycles,
# Nearest to this: addressable, neatly, viper, duty, indexes, easterners, injustices, gauntlets,
# Nearest to its: discriminatory, spellman, rectifiers, infrastructure, dpp, inputs, scouring, bogged,
# Nearest to be: evaluate, doing, bottoms, ambassadorial, i, correct, demonstrating, properties,
# Nearest to gold: totaled, covers, repeal, rainfall, capita, persecutor, burning, boiled,
# Nearest to engine: quake, com, privations, glucose, automobile, sniping, manipulate, goddard,
# Nearest to applications: model, storage, niches, yerba, mode, upgrade, complexes, artificial,
# Nearest to scale: wobbly, asteroids, electrical, tasteless, approximated, polonius, barrie, assortment,
# Nearest to pre: uncertain, bc, earls, miracle, distracted, cabal, trolltech, guinevere,
# Nearest to construction: osage, production, durations, hazmi, parabolic, mayhem, arrangements, landslides,
# Nearest to hold: persuasion, infirmary, paymaster, pitied, borgia, btu, barracuda, tauroctony,
# Nearest to alternative: intuitive, precaution, googolplex, nikolay, tailored, joules, explaining, noblesse,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3752 0.1170 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2956 0.1111 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3807 0.1120 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.4171 0.1132 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4124 0.1127 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2898 0.1131 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3390 0.1116 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3345 0.1109 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2481 0.1128 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3215 0.1134 sec/batch
# Nearest to world: arlo, workers, hay, inflow, linnaeus, michigan, injured, xb,
# Nearest to four: two, three, five, one, six, seven, runways, zero,
# Nearest to th: century, focussing, theobald, flotilla, urbino, jetliner, stead, proverbial,
# Nearest to system: pc, iterated, purporting, joint, vineyard, inflows, authentication, information,
# Nearest to these: portus, endorsement, touchscreen, expressing, the, transcribing, poor, criminal,
# Nearest to this: addressable, neatly, viper, inverse, indexes, gauntlets, landscapes, injustices,
# Nearest to its: discriminatory, infrastructure, defused, climatic, backwater, millimeters, rectifiers, saw,
# Nearest to be: evaluate, doing, bottoms, properties, i, correct, superposition, problems,
# Nearest to gold: totaled, capita, rainfall, repeal, covers, minerals, burning, persecutor,
# Nearest to engine: quake, com, privations, automobile, glucose, sniping, performance, pantheons,
# Nearest to applications: storage, model, niches, complexes, artificial, upgrade, yerba, mode,
# Nearest to scale: wobbly, asteroids, electrical, approximated, polonius, nakajima, tasteless, barrie,
# Nearest to pre: bc, uncertain, distracted, earls, miracle, cabal, lgiy, guinevere,
# Nearest to construction: osage, production, parabolic, hazmi, landslides, mayhem, durations, sloppy,
# Nearest to hold: persuasion, infirmary, paymaster, pitied, tauroctony, btu, insuring, teleoperation,
# Nearest to alternative: intuitive, googolplex, precaution, tailored, nikolay, noblesse, joules, ack,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3419 0.1150 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3417 0.1116 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3545 0.0505 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2576 0.1113 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2650 0.1118 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2304 0.1103 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2617 0.1119 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2070 0.1117 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2816 0.1107 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2060 0.1126 sec/batch
# Nearest to world: workers, arlo, hay, inflow, cfm, xb, injured, linnaeus,
# Nearest to four: two, three, five, one, six, rate, zero, runways,
# Nearest to th: century, focussing, flotilla, theobald, thrace, proverbial, jetliner, urbino,
# Nearest to system: pc, iterated, authentication, vineyard, purporting, joint, initialize, chips,
# Nearest to these: portus, touchscreen, endorsement, transcribing, poor, expressing, sluggish, disregards,
# Nearest to this: addressable, neatly, indexes, viper, marbury, injustices, decrypts, easterners,
# Nearest to its: backwater, discriminatory, scouring, encoding, publicized, inputs, cleves, casteljau,
# Nearest to be: eu, bottoms, doing, ambassadorial, evaluate, eui, ndwandwe, properties,
# Nearest to gold: totaled, capita, covers, repeal, rainfall, minerals, boiled, megadeth,
# Nearest to engine: quake, automobile, com, privations, sniping, performance, improved, goddard,
# Nearest to applications: storage, model, niches, upgrade, yerba, complexes, artificial, mozilla,
# Nearest to scale: wobbly, asteroids, electrical, approximated, nakajima, polonius, barrie, puzzles,
# Nearest to pre: bc, uncertain, distracted, miracle, lgiy, earls, cabal, guinevere,
# Nearest to construction: osage, production, parabolic, landslides, own, hazmi, sloppy, mayhem,
# Nearest to hold: infirmary, tauroctony, paymaster, persuasion, pitied, teleoperation, amount, btu,
# Nearest to alternative: intuitive, nikolay, googolplex, joules, precaution, tapes, explaining, tailored,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2679 0.1126 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2314 0.1132 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2278 0.1120 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1704 0.1143 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1836 0.1135 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1901 0.1139 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1887 0.1138 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.2389 0.1122 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2300 0.1123 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1818 0.1139 sec/batch
# Nearest to world: workers, arlo, inflow, hay, cfm, cheaper, revolutionize, decried,
# Nearest to four: two, three, five, zero, six, one, rate, seven,
# Nearest to th: century, focussing, jetliner, proverbial, flotilla, thrace, urbino, picking,
# Nearest to system: iterated, vineyard, pc, joint, initialize, authentication, purporting, perpetrator,
# Nearest to these: the, touchscreen, cycles, expressing, strict, portus, transcribing, poor,
# Nearest to this: addressable, neatly, marbury, duty, handed, decrypts, indexes, easterners,
# Nearest to its: backwater, scouring, discriminatory, casteljau, publicized, cleves, rectifiers, lifeforms,
# Nearest to be: doing, ambassadorial, evaluate, bottoms, i, eu, correct, ndwandwe,
# Nearest to gold: totaled, capita, repeal, megadeth, drill, covers, minerals, burning,
# Nearest to engine: quake, automobile, com, sniping, casino, zr, privations, improved,
# Nearest to applications: storage, model, niches, yerba, upgrade, complexes, executable, setups,
# Nearest to scale: wobbly, asteroids, electrical, approximated, polonius, tasteless, nakajima, arch,
# Nearest to pre: bc, miracle, uncertain, distracted, lgiy, earls, fishmonger, inked,
# Nearest to construction: osage, parabolic, production, own, landslides, mayhem, hazmi, sloppy,
# Nearest to hold: tauroctony, infirmary, persuasion, btu, paymaster, pitied, teleoperation, concept,
# Nearest to alternative: intuitive, nikolay, googolplex, joules, explaining, ack, precaution, tailored,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.2068 0.1150 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2627 0.1136 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.2182 0.1139 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.2198 0.1132 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2090 0.1128 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1964 0.1149 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1948 0.1133 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1794 0.1119 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1727 0.1117 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.2098 0.1122 sec/batch
# Nearest to world: arlo, workers, revolutionize, cfm, inflow, cheaper, hay, decried,
# Nearest to four: two, three, five, zero, one, six, seven, rate,
# Nearest to th: century, focussing, proverbial, jetliner, theobald, flotilla, thrace, urbino,
# Nearest to system: joint, iterated, purporting, initialize, authentication, pc, filesystems, vineyard,
# Nearest to these: endorsement, portus, strict, expressing, cycles, touchscreen, transcribing, disregards,
# Nearest to this: addressable, neatly, marbury, inverse, consider, quantify, viper, indexes,
# Nearest to its: backwater, scouring, discriminatory, defused, publicized, casteljau, climaxed, great,
# Nearest to be: ambassadorial, bottoms, properties, correct, eu, allowable, i, doing,
# Nearest to gold: totaled, capita, burning, drill, minerals, repeal, covers, megadeth,
# Nearest to engine: quake, automobile, engines, casino, com, privations, mondial, sniping,
# Nearest to applications: storage, model, niches, yerba, sunos, upgrade, complexes, executable,
# Nearest to scale: wobbly, asteroids, electrical, polonius, tasteless, approximated, puzzles, nakajima,
# Nearest to pre: bc, uncertain, miracle, distracted, lgiy, earls, fishmonger, deepest,
# Nearest to construction: parabolic, osage, sloppy, mayhem, hazmi, production, own, landslides,
# Nearest to hold: infirmary, tauroctony, persuasion, btu, paymaster, teleoperation, pitied, adversary,
# Nearest to alternative: intuitive, nikolay, ergodic, precaution, explaining, joules, ack, identically,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2280 0.1132 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1757 0.1137 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1942 0.1118 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1957 0.1132 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1562 0.1137 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1523 0.1120 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.2016 0.1131 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1562 0.1131 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1911 0.1130 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2250 0.1124 sec/batch
# Nearest to world: arlo, workers, revolutionize, cfm, inflow, cracow, hay, virginian,
# Nearest to four: two, three, five, zero, six, one, seven, nine,
# Nearest to th: century, focussing, proverbial, thrace, jetliner, theobald, urbino, hellenistic,
# Nearest to system: iterated, joint, purporting, authentication, tilbury, initialize, pc, whereby,
# Nearest to these: endorsement, disregards, portus, strict, sukarno, expressing, geocachers, cycles,
# Nearest to this: addressable, marbury, neatly, arianism, affirms, consider, duty, gentiles,
# Nearest to its: backwater, defused, scouring, discriminatory, publicized, overvalued, directv, nominally,
# Nearest to be: ambassadorial, eu, bottoms, i, correct, allowable, conspiring, doing,
# Nearest to gold: totaled, drill, capita, megadeth, precious, burning, lendl, covers,
# Nearest to engine: quake, automobile, engines, antimicrobial, casino, sniping, knocking, privations,
# Nearest to applications: storage, niches, model, mozilla, sunos, upgrade, yerba, complexes,
# Nearest to scale: wobbly, asteroids, electrical, polonius, tasteless, approximated, puzzles, nakajima,
# Nearest to pre: uncertain, bc, distracted, miracle, lgiy, earls, aurelius, fishmonger,
# Nearest to construction: osage, parabolic, hazmi, mayhem, landslides, industrial, sloppy, production,
# Nearest to hold: infirmary, tauroctony, persuasion, paymaster, adversary, teleoperation, btu, pitied,
# Nearest to alternative: nikolay, intuitive, ack, joules, explaining, precaution, ergodic, binghamton,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2763 0.1131 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1591 0.1130 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1709 0.1120 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1471 0.1129 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0581 0.1116 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1566 0.1135 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1500 0.1125 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1648 0.1132 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.2133 0.0186 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1586 0.1124 sec/batch
# Nearest to world: arlo, revolutionize, workers, inflow, cfm, cheaper, hay, cabins,
# Nearest to four: two, three, five, zero, one, six, seven, nine,
# Nearest to th: century, focussing, proverbial, jetliner, thrace, flotilla, hellenistic, burgundians,
# Nearest to system: pc, purporting, iterated, authentication, filesystems, workstation, portability, customizing,
# Nearest to these: endorsement, cycles, mediated, geocachers, markka, sluggish, portus, strict,
# Nearest to this: neatly, addressable, marbury, duty, consider, catechisms, inverse, affirms,
# Nearest to its: backwater, defused, discriminatory, overvalued, publicized, casteljau, scouring, lifeforms,
# Nearest to be: ambassadorial, eu, i, bottoms, allowable, moslems, correct, properties,
# Nearest to gold: totaled, drill, megadeth, precious, capita, burning, covers, rearrangement,
# Nearest to engine: quake, automobile, engines, antimicrobial, sniping, casino, knocking, mondial,
# Nearest to applications: storage, sunos, niches, mozilla, model, setups, upgrade, yerba,
# Nearest to scale: wobbly, asteroids, polonius, electrical, puzzles, approximated, barrie, mozambique,
# Nearest to pre: bc, uncertain, distracted, lgiy, miracle, morte, aurelius, fishmonger,
# Nearest to construction: osage, parabolic, hazmi, industrial, landslides, mayhem, sloppy, mcdonalds,
# Nearest to hold: infirmary, tauroctony, paymaster, adversary, teleoperation, persuasion, btu, pitied,
# Nearest to alternative: joules, intuitive, ergodic, nikolay, ack, googolplex, identically, precaution,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0907 0.1132 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0944 0.1123 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1043 0.1114 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0774 0.1097 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.1082 0.1148 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0785 0.1122 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1077 0.1118 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0940 0.1119 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1140 0.1129 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0682 0.1143 sec/batch
# Nearest to world: arlo, revolutionize, workers, inflow, cfm, cheaper, hay, alcindor,
# Nearest to four: two, three, five, zero, one, six, seven, nine,
# Nearest to th: century, focussing, rd, jetliner, burgundians, proverbial, thrace, nd,
# Nearest to system: purporting, pc, joint, listings, tilbury, vineyard, workstation, initialize,
# Nearest to these: endorsement, sluggish, portus, the, geocachers, templo, transcribing, markka,
# Nearest to this: addressable, marbury, of, neatly, duty, injustices, viper, compels,
# Nearest to its: backwater, scouring, the, defused, casteljau, discriminatory, saw, great,
# Nearest to be: ambassadorial, eu, bottoms, allowable, i, doing, detoxification, demonstrating,
# Nearest to gold: totaled, precious, drill, megadeth, capita, burning, lendl, richly,
# Nearest to engine: automobile, quake, engines, sniping, mondial, casino, antimicrobial, knocking,
# Nearest to applications: storage, sunos, setups, mozilla, niches, model, upgrade, bushnell,
# Nearest to scale: wobbly, asteroids, puzzles, polonius, approximated, mozambique, barrie, tasteless,
# Nearest to pre: bc, distracted, aurelius, uncertain, lgiy, earls, miracle, morte,
# Nearest to construction: parabolic, osage, own, hazmi, advent, mayhem, industrial, sloppy,
# Nearest to hold: tauroctony, infirmary, add, persuasion, btu, teleoperation, adversary, paymaster,
# Nearest to alternative: joules, nikolay, intuitive, identically, ergodic, explaining, ack, googolplex,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0344 0.1154 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0328 0.1126 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0534 0.1135 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.1006 0.1133 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0972 0.1115 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0768 0.1122 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0575 0.1128 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1219 0.1118 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0897 0.1137 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0525 0.1129 sec/batch
# Nearest to world: revolutionize, arlo, cfm, inflow, workers, cheaper, hay, cabins,
# Nearest to four: two, three, five, zero, six, one, seven, nine,
# Nearest to th: century, focussing, rd, jetliner, nd, proverbial, burgundians, cassel,
# Nearest to system: purporting, joint, vineyard, iterated, tilbury, initialize, authentication, privatised,
# Nearest to these: geocachers, strict, expressing, endorsement, cycles, templo, mediated, classified,
# Nearest to this: addressable, neatly, duty, marbury, of, consider, inverse, quantify,
# Nearest to its: backwater, scouring, the, lifeforms, casteljau, discriminatory, algebras, quite,
# Nearest to be: ambassadorial, i, allowable, that, eu, detoxification, doing, bottoms,
# Nearest to gold: totaled, precious, drill, megadeth, richly, lendl, burning, mined,
# Nearest to engine: engines, quake, automobile, mondial, antimicrobial, sniping, babbage, knocking,
# Nearest to applications: storage, sunos, setups, niches, model, yerba, mozilla, windu,
# Nearest to scale: wobbly, asteroids, puzzles, polonius, barrie, approximated, arch, mozambique,
# Nearest to pre: distracted, bc, lgiy, uncertain, deepest, aurelius, fishmonger, miracle,
# Nearest to construction: parabolic, own, industrial, advent, osage, hazmi, sloppy, mayhem,
# Nearest to hold: tauroctony, infirmary, add, teleoperation, persuasion, adversary, btu, evangelical,
# Nearest to alternative: nikolay, joules, intuitive, identically, ergodic, ack, tuskegee, explaining,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.1082 0.1138 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1200 0.1132 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0986 0.1134 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0866 0.1102 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.1017 0.1112 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0494 0.1124 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0726 0.1139 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0919 0.1118 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1149 0.1129 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0742 0.1111 sec/batch
# Nearest to world: arlo, revolutionize, cfm, inflow, workers, seeded, decried, cabins,
# Nearest to four: two, three, five, zero, one, six, seven, nine,
# Nearest to th: century, rd, focussing, centuries, nd, burgundians, thrace, conquests,
# Nearest to system: joint, tilbury, purporting, vineyard, privatised, bae, telecom, listings,
# Nearest to these: endorsement, expressing, submissive, strict, pastoral, portus, templo, cycles,
# Nearest to this: of, neatly, annapolis, marbury, addressable, arianism, consider, easterners,
# Nearest to its: backwater, the, zafy, galatia, defused, discriminatory, great, scouring,
# Nearest to be: ambassadorial, eu, bottoms, allowable, i, detoxification, doing, correct,
# Nearest to gold: totaled, precious, drill, megadeth, richly, mined, burning, lendl,
# Nearest to engine: quake, engines, automobile, mondial, babbage, antimicrobial, sniping, knocking,
# Nearest to applications: sunos, setups, storage, mozilla, yerba, niches, windu, expandability,
# Nearest to scale: wobbly, asteroids, puzzles, barrie, polonius, approximated, mozambique, oiling,
# Nearest to pre: bc, distracted, uncertain, aurelius, miracle, lgiy, earls, fishmonger,
# Nearest to construction: parabolic, industrial, osage, hazmi, advent, mayhem, own, sloppy,
# Nearest to hold: tauroctony, infirmary, add, adversary, teleoperation, persuasion, btu, amount,
# Nearest to alternative: nikolay, joules, intuitive, identically, ergodic, classless, dartmouth, ack,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0658 0.1149 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0542 0.1141 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0456 0.1133 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0886 0.1142 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0897 0.1120 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1691 0.1131 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1239 0.1126 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0569 0.1137 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0628 0.1127 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0776 0.1126 sec/batch
# Nearest to world: arlo, revolutionize, cfm, inflow, workers, seeded, cabins, virginian,
# Nearest to four: two, three, five, zero, one, six, seven, nine,
# Nearest to th: century, focussing, rd, nd, centuries, burgundians, proverbial, thrace,
# Nearest to system: joint, tilbury, purporting, filesystems, privatised, workstation, listings, bae,
# Nearest to these: classified, endorsement, geocachers, portus, strict, submissive, xiamen, among,
# Nearest to this: addressable, neatly, consider, of, marbury, arianism, quantify, duty,
# Nearest to its: backwater, the, defused, zafy, overvalued, saw, nominally, integration,
# Nearest to be: i, allowable, eu, ambassadorial, bottoms, correct, that, detoxification,
# Nearest to gold: totaled, precious, drill, richly, megadeth, mined, minted, offered,
# Nearest to engine: engines, quake, automobile, mondial, antimicrobial, babbage, sniping, knocking,
# Nearest to applications: sunos, setups, mozilla, storage, yerba, niches, expandability, bushnell,
# Nearest to scale: wobbly, asteroids, puzzles, barrie, approximated, mozambique, polonius, were,
# Nearest to pre: uncertain, distracted, bc, aurelius, lgiy, faroese, deepest, fishmonger,
# Nearest to construction: parabolic, industrial, hazmi, osage, advent, own, sloppy, mcdonalds,
# Nearest to hold: tauroctony, infirmary, teleoperation, add, persuasion, adversary, btu, evangelical,
# Nearest to alternative: nikolay, ergodic, joules, intuitive, identically, classless, ack, binghamton,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9990 0.1135 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0391 0.1127 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0656 0.1127 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0568 0.1116 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0884 0.1133 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0621 0.0989 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0387 0.1122 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9951 0.1115 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0331 0.1114 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 4.0095 0.1119 sec/batch
# Nearest to world: revolutionize, arlo, cfm, inflow, seeded, workers, ultimate, virginian,
# Nearest to four: two, three, zero, five, one, six, seven, nine,
# Nearest to th: century, rd, focussing, nd, proverbial, centuries, burgundians, ionia,
# Nearest to system: joint, purporting, tilbury, initialize, filesystems, customizing, vineyard, listings,
# Nearest to these: geocachers, classified, cycles, mediated, endorsement, submissive, touchscreen, portus,
# Nearest to this: of, addressable, neatly, arianism, compels, scrolling, rectifying, consider,
# Nearest to its: backwater, the, quite, scouring, galatia, letter, zafy, notably,
# Nearest to be: eu, ambassadorial, detoxification, bottoms, moslems, allowable, doing, i,
# Nearest to gold: totaled, precious, drill, minted, megadeth, mined, richly, tin,
# Nearest to engine: engines, quake, automobile, babbage, mondial, sniping, antimicrobial, knocking,
# Nearest to applications: sunos, mozilla, setups, storage, niches, yerba, bushnell, upgrade,
# Nearest to scale: wobbly, asteroids, puzzles, barrie, were, approximated, polonius, mozambique,
# Nearest to pre: aurelius, distracted, uncertain, bc, lgiy, guinevere, miracle, remnants,
# Nearest to construction: industrial, hazmi, parabolic, osage, advent, building, own, mcdonalds,
# Nearest to hold: tauroctony, persuasion, teleoperation, add, infirmary, adversary, btu, evangelical,
# Nearest to alternative: nikolay, joules, intuitive, ergodic, classless, identically, binghamton, explaining,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0285 0.1128 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9741 0.1122 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0570 0.1116 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0256 0.1155 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0409 0.1126 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0217 0.1123 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9226 0.1130 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9800 0.1139 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9592 0.1138 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9899 0.1139 sec/batch
# Nearest to world: arlo, revolutionize, cfm, inflow, seeded, workers, decried, cheaper,
# Nearest to four: two, three, zero, five, one, six, seven, nine,
# Nearest to th: century, focussing, rd, nd, centuries, proverbial, ionia, jetliner,
# Nearest to system: tilbury, joint, purporting, initialize, vineyard, privatised, listings, employ,
# Nearest to these: geocachers, cycles, classified, submissive, the, strict, endorsement, various,
# Nearest to this: addressable, of, neatly, consider, gemellus, marbury, arianism, quantify,
# Nearest to its: the, backwater, quite, scouring, overvalued, notably, galatia, derived,
# Nearest to be: ambassadorial, allowable, that, detoxification, eu, bottoms, for, is,
# Nearest to gold: totaled, precious, minted, drill, mined, megadeth, tin, richly,
# Nearest to engine: engines, automobile, quake, babbage, mondial, sniping, antimicrobial, knocking,
# Nearest to applications: sunos, yerba, setups, storage, mozilla, niches, bushnell, windu,
# Nearest to scale: wobbly, asteroids, puzzles, barrie, approximated, polonius, oiling, were,
# Nearest to pre: bc, uncertain, distracted, aurelius, lgiy, remnants, deepest, ethnolinguistic,
# Nearest to construction: industrial, own, advent, hazmi, parabolic, building, osage, foundations,
# Nearest to hold: tauroctony, add, teleoperation, infirmary, persuasion, adversary, evangelical, btu,
# Nearest to alternative: nikolay, intuitive, identically, ergodic, joules, classless, explaining, anarchists,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0212 0.1150 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0184 0.1130 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9586 0.1130 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0266 0.1125 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0662 0.1119 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9887 0.1123 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0004 0.1135 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0242 0.1128 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9997 0.1117 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0166 0.1127 sec/batch
# Nearest to world: arlo, revolutionize, cfm, inflow, seeded, ultimate, workers, decried,
# Nearest to four: two, three, zero, five, one, six, nine, seven,
# Nearest to th: century, rd, focussing, nd, jetliner, ionia, proverbial, physicists,
# Nearest to system: tilbury, joint, bae, engset, initialize, privatised, listings, overwritten,
# Nearest to these: cycles, geocachers, submissive, endorsement, classified, strict, among, mediated,
# Nearest to this: addressable, of, neatly, consider, to, annapolis, distribution, scrolling,
# Nearest to its: the, backwater, zafy, defused, overvalued, quite, scouring, on,
# Nearest to be: ambassadorial, eu, bottoms, allowable, that, naturals, detoxification, moslems,
# Nearest to gold: totaled, precious, minted, drill, mined, megadeth, tin, offered,
# Nearest to engine: engines, quake, automobile, babbage, mondial, sniping, antimicrobial, piston,
# Nearest to applications: sunos, mozilla, setups, yerba, niches, storage, windu, expandability,
# Nearest to scale: wobbly, asteroids, puzzles, barrie, approximated, polonius, oiling, anak,
# Nearest to pre: distracted, bc, aurelius, uncertain, lgiy, charts, fishmonger, miracle,
# Nearest to construction: industrial, parabolic, advent, hazmi, foundations, sloppy, bell, building,
# Nearest to hold: tauroctony, add, teleoperation, infirmary, persuasion, adversary, evangelical, anions,
# Nearest to alternative: nikolay, joules, classless, ergodic, identically, explaining, intuitive, tuskegee,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0129 0.1128 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.0196 0.1115 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0096 0.1110 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0307 0.1118 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0235 0.1109 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0120 0.1122 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9896 0.1146 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 4.0036 0.1139 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 4.0002 0.1145 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0082 0.1154 sec/batch
# Nearest to world: revolutionize, arlo, cfm, inflow, seeded, ultimate, decried, workers,
# Nearest to four: two, three, zero, five, one, six, seven, nine,
# Nearest to th: century, focussing, rd, nd, centuries, jetliner, ionia, burgundians,
# Nearest to system: tilbury, joint, privatised, purporting, bae, engset, employ, initialize,
# Nearest to these: the, classified, submissive, geocachers, cycles, among, endorsement, mediated,
# Nearest to this: of, addressable, neatly, to, quantify, easing, distribution, eight,
# Nearest to its: the, zafy, on, overvalued, defused, backwater, great, quite,
# Nearest to be: ambassadorial, eu, for, detoxification, allowable, that, not, fixed,
# Nearest to gold: precious, totaled, minted, mined, drill, tin, minerals, richly,
# Nearest to engine: engines, quake, automobile, babbage, mondial, pistons, piston, sniping,
# Nearest to applications: sunos, mozilla, setups, yerba, niches, storage, ringworld, complexes,
# Nearest to scale: wobbly, asteroids, puzzles, barrie, oiling, polonius, approximated, tasteless,
# Nearest to pre: bc, aurelius, distracted, remnants, uncertain, lgiy, charts, fishmonger,
# Nearest to construction: industrial, advent, parabolic, foundations, building, own, osage, bell,
# ...
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8659 0.1120 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.9055 0.1130 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8522 0.1133 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8810 0.1124 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9569 0.1120 sec/batch
# Nearest to world: revolutionize, cfm, arlo, milestone, chess, hernandez, won, ultimate,
# Nearest to four: two, three, zero, one, five, six, eight, seven,
# Nearest to th: century, rd, nd, today, centuries, cassel, conf, early,
# Nearest to system: systems, joint, plus, tilbury, electrified, deferred, shakti, lines,
# Nearest to these: other, some, are, and, classified, among, cytosol, the,
# Nearest to this: to, the, of, a, it, particular, in, with,
# Nearest to its: the, of, on, a, is, in, located, photosphere,
# Nearest to be: for, that, is, a, of, an, not, or,
# Nearest to gold: minted, silver, plural, totaled, precious, drill, lendl, megadeth,
# Nearest to engine: engines, quake, babbage, pistons, driven, piston, mondial, stroke,
# Nearest to applications: mozilla, enlarged, prentice, application, setups, expressivity, niches, stanislaw,
# Nearest to scale: tarn, barrie, oiling, anak, olwen, puzzles, erected, scribner,
# Nearest to pre: neolithic, yyyy, remnants, post, charts, subsidiary, distracted, deepest,
# Nearest to construction: industrial, building, shingles, architects, constructed, mayhem, foundations, theologico,
# Nearest to hold: add, teleoperation, persuasion, exaltation, tauroctony, narrower, poker, utilize,
# Nearest to alternative: cure, nikolay, it, ergodic, noblesse, xemacs, traced, internship,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8542 0.1145 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8673 0.1137 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8789 0.1131 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8786 0.1110 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8921 0.1127 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.9249 0.1135 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8951 0.1129 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8851 0.1117 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8962 0.1100 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8828 0.1117 sec/batch
# Nearest to world: revolutionize, chess, cfm, arlo, milestone, hernandez, nations, ultimate,
# Nearest to four: two, three, one, zero, five, six, seven, eight,
# Nearest to th: century, rd, nd, centuries, today, focussing, early, malthus,
# Nearest to system: systems, joint, plus, tilbury, lines, deferred, electrified, privatised,
# Nearest to these: some, other, among, are, classified, and, various, cytosol,
# Nearest to this: to, the, of, it, one, personages, particular, a,
# Nearest to its: the, of, on, a, located, photosphere, as, is,
# Nearest to be: for, that, is, a, or, not, containing, an,
# Nearest to gold: minted, silver, precious, totaled, plural, megadeth, copper, drill,
# Nearest to engine: engines, quake, babbage, mondial, pistons, driven, piston, stroke,
# Nearest to applications: mozilla, application, enlarged, prentice, polyester, stanislaw, molds, windu,
# Nearest to scale: barrie, tarn, oiling, anak, olwen, scales, puzzles, erected,
# Nearest to pre: yyyy, neolithic, charts, remnants, post, subsidiary, nicol, distracted,
# Nearest to construction: industrial, building, shingles, theologico, storey, silla, architects, constructed,
# Nearest to hold: add, persuasion, teleoperation, exaltation, utilize, adversary, narrower, tauroctony,
# Nearest to alternative: cure, nikolay, it, noblesse, ergodic, traced, tuskegee, tiger,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8708 0.1131 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8873 0.1131 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8460 0.1140 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8881 0.1125 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8981 0.1148 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8386 0.1116 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9875 0.1125 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9526 0.1124 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9407 0.1145 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8424 0.1137 sec/batch
# Nearest to world: revolutionize, arlo, chess, milestone, nations, hernandez, ultimate, inflow,
# Nearest to four: two, three, zero, five, one, six, seven, eight,
# Nearest to th: century, rd, nd, centuries, today, early, focussing, outpaced,
# Nearest to system: systems, joint, plus, tilbury, shakti, deferred, regulate, electrified,
# Nearest to these: other, some, among, are, and, classified, the, various,
# Nearest to this: to, of, the, it, an, personages, one, a,
# Nearest to its: the, of, a, on, in, as, located, which,
# Nearest to be: for, that, is, or, not, an, of, containing,
# Nearest to gold: minted, silver, precious, totaled, plural, mined, megadeth, drill,
# Nearest to engine: engines, quake, pistons, babbage, mondial, piston, jet, bosch,
# Nearest to applications: mozilla, application, prentice, enlarged, stanislaw, windu, troika, dino,
# Nearest to scale: barrie, tarn, oiling, olwen, anak, scribner, liverpudlians, puzzles,
# Nearest to pre: yyyy, neolithic, charts, post, remnants, subsidiary, distracted, nicol,
# Nearest to construction: industrial, building, shingles, galatian, mayhem, theologico, marne, locks,
# Nearest to hold: add, persuasion, utilize, exaltation, teleoperation, playlists, adversary, poker,
# Nearest to alternative: cure, nikolay, ergodic, it, noblesse, internship, preprocessing, matth,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8337 0.1128 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8863 0.1117 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7795 0.1125 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.9018 0.1126 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8624 0.1135 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8503 0.1124 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9186 0.0540 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8416 0.1118 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8622 0.1125 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8331 0.1117 sec/batch
# Nearest to world: revolutionize, chess, arlo, milestone, ultimate, hernandez, obvious, strongest,
# Nearest to four: two, three, zero, one, five, six, seven, eight,
# Nearest to th: century, rd, nd, today, centuries, focussing, early, cassel,
# Nearest to system: systems, plus, tilbury, joint, shakti, lines, kt, deferred,
# Nearest to these: some, other, are, and, classified, among, various, cytosol,
# Nearest to this: to, the, it, of, in, an, personages, a,
# Nearest to its: the, of, a, in, on, is, as, which,
# Nearest to be: for, that, a, is, an, of, not, or,
# Nearest to gold: minted, silver, precious, totaled, plural, mined, covers, drill,
# Nearest to engine: engines, quake, babbage, pistons, mondial, bosch, piston, driven,
# Nearest to applications: mozilla, prentice, application, ensured, windu, supervillain, enlarged, integrate,
# Nearest to scale: barrie, tarn, oiling, olwen, scales, anak, liverpudlians, seventh,
# Nearest to pre: yyyy, neolithic, post, charts, subsidiary, remnants, nicol, distracted,
# Nearest to construction: building, industrial, shingles, galatian, mayhem, marne, theologico, silla,
# Nearest to hold: persuasion, add, teleoperation, narrower, utilize, exaltation, playlists, tauroctony,
# Nearest to alternative: cure, nikolay, treatments, ergodic, quackery, noblesse, morrie, internship,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8710 0.1133 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8569 0.1120 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8586 0.1112 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8103 0.1119 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8779 0.1113 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8338 0.1123 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8730 0.1131 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7711 0.1147 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8475 0.1139 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8209 0.1145 sec/batch
# Nearest to world: revolutionize, chess, milestone, arlo, hernandez, cfm, seeded, obvious,
# Nearest to four: two, three, zero, one, five, six, seven, eight,
# Nearest to th: century, rd, nd, today, centuries, early, focussing, outpaced,
# Nearest to system: systems, plus, shakti, tilbury, joint, lines, electrified, regulate,
# Nearest to these: other, some, and, are, classified, among, they, various,
# Nearest to this: to, the, it, a, in, an, of, from,
# Nearest to its: the, of, a, in, is, on, also, located,
# Nearest to be: for, that, is, an, a, or, not, of,
# Nearest to gold: minted, silver, precious, totaled, plural, lendl, mined, drill,
# Nearest to engine: engines, babbage, pistons, quake, mondial, piston, driven, bosch,
# Nearest to applications: mozilla, enlarged, ensured, windu, application, prentice, stanislaw, integrate,
# Nearest to scale: barrie, tarn, oiling, olwen, scales, seventh, anak, scribner,
# Nearest to pre: post, yyyy, neolithic, charts, remnants, subsidiary, mixtec, distracted,
# Nearest to construction: building, industrial, shingles, constructions, mayhem, theologico, galatian, tractates,
# Nearest to hold: add, persuasion, narrower, teleoperation, utilize, exaltation, playlists, poker,
# Nearest to alternative: cure, nikolay, treatments, quackery, traced, ergodic, also, noblesse,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7608 0.1161 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8645 0.1140 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8879 0.1128 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8655 0.1139 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8417 0.1112 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9126 0.1123 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8706 0.1111 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8071 0.1123 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8694 0.1122 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8797 0.1118 sec/batch
# Nearest to world: revolutionize, chess, milestone, arlo, ultimate, cfm, nations, hernandez,
# Nearest to four: two, three, zero, five, one, seven, six, eight,
# Nearest to th: century, rd, nd, early, focussing, today, centuries, cassel,
# Nearest to system: systems, plus, joint, shakti, lines, regulate, deferred, tilbury,
# Nearest to these: some, other, are, and, among, classified, various, they,
# Nearest to this: to, the, it, in, an, of, a, with,
# Nearest to its: the, of, a, in, is, which, on, also,
# Nearest to be: for, that, a, an, of, or, is, not,
# Nearest to gold: minted, silver, totaled, plural, precious, covers, drill, megadeth,
# Nearest to engine: engines, quake, babbage, pistons, mondial, stroke, bosch, driven,
# Nearest to applications: mozilla, enlarged, windu, ensured, stanislaw, prentice, casale, integrate,
# Nearest to scale: barrie, oiling, tarn, scales, olwen, seventh, puzzles, anak,
# Nearest to pre: post, yyyy, neolithic, charts, distracted, subsidiary, remnants, prasse,
# Nearest to construction: building, industrial, mayhem, constructions, constructed, galatian, theologico, shingles,
# Nearest to hold: add, persuasion, utilize, exaltation, narrower, poker, teleoperation, playlists,
# Nearest to alternative: cure, nikolay, ergodic, also, traced, it, treatments, ambit,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8887 0.1153 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8659 0.1124 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7980 0.1134 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8773 0.1121 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8951 0.1110 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8546 0.1121 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8438 0.1122 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8760 0.1123 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8228 0.1134 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8264 0.1131 sec/batch
# Nearest to world: revolutionize, chess, nations, in, milestone, obvious, ultimate, firmly,
# Nearest to four: two, three, zero, one, five, six, seven, eight,
# Nearest to th: century, rd, nd, centuries, early, today, focussing, earliest,
# Nearest to system: systems, plus, joint, shakti, regulate, sunga, tilbury, lines,
# Nearest to these: other, some, and, are, among, classified, of, the,
# Nearest to this: to, the, in, of, it, one, an, with,
# Nearest to its: the, of, a, in, on, which, is, as,
# Nearest to be: for, that, or, is, an, of, a, other,
# Nearest to gold: minted, silver, precious, totaled, plural, mined, baskets, megadeth,
# Nearest to engine: engines, quake, pistons, babbage, mondial, piston, driven, bosch,
# Nearest to applications: mozilla, ensured, enlarged, prentice, stanislaw, offensive, application, molds,
# Nearest to scale: oiling, barrie, tarn, seventh, olwen, scales, scribner, anak,
# Nearest to pre: neolithic, yyyy, post, charts, remnants, subsidiary, prasse, nicol,
# Nearest to construction: building, industrial, mayhem, constructed, theologico, constructions, shingles, locks,
# Nearest to hold: persuasion, add, utilize, narrower, exaltation, similar, playlists, teleoperation,
# Nearest to alternative: cure, nikolay, it, ergodic, treatments, also, arafat, noblesse,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8808 0.1148 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8340 0.1151 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9337 0.1126 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9359 0.1125 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9144 0.1123 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8783 0.1128 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.8241 0.1132 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8230 0.1099 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7549 0.1124 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8610 0.1138 sec/batch
# Nearest to world: revolutionize, chess, arlo, firmly, obvious, nations, in, vital,
# Nearest to four: two, three, zero, one, five, seven, six, eight,
# Nearest to th: century, rd, nd, today, centuries, early, focussing, cassel,
# Nearest to system: systems, plus, joint, shakti, lines, regulate, tilbury, deferred,
# Nearest to these: some, other, and, are, among, classified, of, various,
# Nearest to this: to, the, it, an, in, of, from, a,
# Nearest to its: the, of, a, in, on, is, was, which,
# Nearest to be: for, that, an, or, not, a, is, of,
# Nearest to gold: minted, silver, totaled, precious, plural, mined, baskets, copper,
# Nearest to engine: engines, quake, pistons, babbage, mondial, piston, jet, bosch,
# Nearest to applications: mozilla, application, prentice, offensive, stanislaw, ensured, enlarged, molds,
# Nearest to scale: oiling, tarn, barrie, olwen, seventh, scales, erected, scribner,
# Nearest to pre: post, neolithic, yyyy, subsidiary, remnants, distracted, nicol, bogus,
# Nearest to construction: building, industrial, theologico, mayhem, constructed, shingles, marne, constructions,
# Nearest to hold: utilize, persuasion, add, exaltation, narrower, teleoperation, reparations, rationals,
# Nearest to alternative: cure, nikolay, ergodic, noblesse, traced, arafat, treatments, it,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8667 0.1117 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8596 0.1128 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
